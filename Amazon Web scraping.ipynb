# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
w = webdriver.Chrome()

# %%
w.get("https://www.amazon.eg/s?k=samsung&rh=p_89%3Asamsung&language=en&ref=SQEG-WEB-SR301")

# %%
products = w.find_elements(By.PATH, "//div[@class='a-section a-spacing-base']")

# %%
data = []
for product in products:
    try:
        title_element = product.find_element(By.XPATH, ".//span[@class='a-size-base-plus a-color-base']")
        title = title_element.text

        description_element = product.find_element(By.XPATH, ".//span[@class='a-size-base-plus a-color-base a-text-normal']")
        description = description_element.text

        image_element = product.find_element(By.XPATH, ".//img[@class='s-image']")
        image_url = image_element.get_attribute('src')


        rating_element = product.find_element(By.XPATH, ".//div[@class='a-row a-size-small']/span").get_attribute('aria-label')
        rating = rating_element.strip()
        if not rating:
            rating = "No rating"

        total_ratings_element = product.find_element(By.XPATH, ".//span[@class='a-size-base s-underline-text']")
        total_ratings = total_ratings_element.text
    except:
        print("No Data")

    print(f"Title: {title}")
    print(f"Description: {description}")
    print(f"Image URL: {image_url}")
    print(f"Rating: {rating}")
    print(f"Total Ratings: {total_ratings}")
    print("-" * 40)

    data.append({
        'Title': title,
        'Description': description,
        'Rating': rating,
        'Total Ratings': total_ratings,
        'Image URL': image_url
    })
df = pd.DataFrame(data)
csv_file = 'amazon_products.csv'
df.to_csv(csv_file, index=False, encoding='utf-8')
# Out:
# Title: SAMSUNG
# Description: Galaxy A15 Dual SIM 6GB Ram+128GB ROM (6.5 Inches) (4G LTE) - (Light Blue)
# Image URL: https://m.media-amazon.com/images/I/61cl1NEIrdL._AC_UL320_.jpg
# Rating: 4.0 out of 5 stars
# Total Ratings: 851
# ----------------------------------------
# Title: SAMSUNG
# Description: Galaxy A35 5G, Android Smartphone, Dual SIM Mobile Phone, 8GB RAM, 256GB Storage, Awesome Navy
# Image URL: https://m.media-amazon.com/images/I/61Dz4UF90XL._AC_UL320_.jpg
# Rating: 4.1 out of 5 stars
# Total Ratings: 51
# ----------------------------------------
# Title: SAMSUNG
# Description: A04S 3GB Ram, 32GB - Black
# Image URL: https://m.media-amazon.com/images/I/51P4huodC+L._AC_UL320_.jpg
# Rating: 3.8 out of 5 stars
# Total Ratings: 42
# ----------------------------------------
# Title: SAMSUNG
# Description: Galaxy A05 LTE, Android Smartphone, Dual SIM Mobile Phone, 4GB RAM, 128GB Storage, Black
# Image URL: https://m.media-amazon.com/images/I/71dYQdmhwFL._AC_UL320_.jpg
# ...
